# %%
from ipynb.fs.full.weather_pipeline import WeatherPipeline

# %%
# Configuration dictionary
config = {
    'data_path': './../data/',
    'file_name': 'weather_dataset_preprocesado.csv',
    #'columns_dataset': ['datetime', 'p (mbar)', 'T (degC)', 'Tpot (K)'], 
    'column_target': 'T (degC)',   
    'input_length': 24,
    'output_length': 1,
    'epochs': 20,
    'batch_size': 256,
    'learning_rate': 5e-4, #2.8e-4,
    'n_units': 256,
    'plot': True,
    'feature_engineering': True
}

pipeline = WeatherPipeline(config)
pipeline.run()
# Out:
# c:\Sevann\UBA\LSMT-weather\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 157/157 - 37s - 239ms/step - loss: 0.0666 - val_loss: 0.0364 - learning_rate: 5.0000e-04
# Epoch 2/20
# 157/157 - 32s - 205ms/step - loss: 0.0405 - val_loss: 0.0269 - learning_rate: 5.0000e-04
# Epoch 3/20
# 157/157 - 35s - 222ms/step - loss: 0.0346 - val_loss: 0.0254 - learning_rate: 5.0000e-04
# Epoch 4/20
# 157/157 - 35s - 225ms/step - loss: 0.0328 - val_loss: 0.0237 - learning_rate: 5.0000e-04
# Epoch 5/20
# 157/157 - 31s - 198ms/step - loss: 0.0316 - val_loss: 0.0237 - learning_rate: 5.0000e-04
# Epoch 6/20
# 157/157 - 33s - 207ms/step - loss: 0.0305 - val_loss: 0.0247 - learning_rate: 5.0000e-04
# Epoch 7/20
# 157/157 - 31s - 196ms/step - loss: 0.0301 - val_loss: 0.0232 - learning_rate: 5.0000e-04
# Epoch 8/20
# 157/157 - 32s - 205ms/step - loss: 0.0299 - val_loss: 0.0234 - learning_rate: 5.0000e-04
# Epoch 9/20
# 157/157 - 32s - 204ms/step - loss: 0.0294 - val_loss: 0.0228 - learning_rate: 5.0000e-04
# Epoch 10/20
# 157/157 - 32s - 202ms/step - loss: 0.0292 - val_loss: 0.0228 - learning_rate: 5.0000e-04
# Epoch 11/20
# 157/157 - 33s - 209ms/step - loss: 0.0291 - val_loss: 0.0227 - learning_rate: 5.0000e-04
# Epoch 12/20
# 157/157 - 32s - 207ms/step - loss: 0.0289 - val_loss: 0.0237 - learning_rate: 5.0000e-04
# Epoch 13/20
# 157/157 - 31s - 199ms/step - loss: 0.0281 - val_loss: 0.0226 - learning_rate: 2.5000e-04
# Epoch 14/20
# 157/157 - 32s - 202ms/step - loss: 0.0280 - val_loss: 0.0234 - learning_rate: 2.5000e-04
# Epoch 15/20
# 157/157 - 33s - 208ms/step - loss: 0.0280 - val_loss: 0.0227 - learning_rate: 2.5000e-04
# Epoch 16/20
# 157/157 - 32s - 205ms/step - loss: 0.0279 - val_loss: 0.0227 - learning_rate: 2.5000e-04
# Epoch 17/20
# 157/157 - 34s - 217ms/step - loss: 0.0276 - val_loss: 0.0227 - learning_rate: 1.2500e-04
# Epoch 18/20
# 157/157 - 31s - 196ms/step - loss: 0.0276 - val_loss: 0.0225 - learning_rate: 1.2500e-04
# Epoch 19/20
# 157/157 - 33s - 213ms/step - loss: 0.0275 - val_loss: 0.0227 - learning_rate: 1.2500e-04
# Epoch 20/20
# 157/157 - 31s - 199ms/step - loss: 0.0274 - val_loss: 0.0225 - learning_rate: 6.2500e-05
# RMSE Comparison:
#   RMSE Train: 0.022
#   RMSE Val: 0.022
#   RMSE Test: 0.026
