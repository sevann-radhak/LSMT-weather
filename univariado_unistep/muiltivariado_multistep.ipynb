# %%
from ipynb.fs.full.weather_pipeline import WeatherPipeline

# %%
# Configuration dictionary
config = {
    'data_path': './../data/',
    'file_name': 'weather_dataset_preprocesado.csv',
    #'columns_dataset': ['datetime', 'p (mbar)', 'T (degC)', 'Tpot (K)'], 
    'column_target': 'T (degC)',   
    'input_length': 24,
    'output_length': 4,
    'epochs': 20,
    'batch_size': 256,
    'learning_rate': 5e-4, #2.8e-4,
    'n_units': 256,
    'plot': True,
    'feature_engineering': True
}

pipeline = WeatherPipeline(config)
pipeline.run()
# Out:
# c:\Sevann\UBA\LSMT-weather\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 157/157 - 38s - 244ms/step - loss: 0.0937 - val_loss: 0.0599 - learning_rate: 5.0000e-04
# Epoch 2/20
# 157/157 - 30s - 190ms/step - loss: 0.0648 - val_loss: 0.0510 - learning_rate: 5.0000e-04
# Epoch 3/20
# 157/157 - 35s - 221ms/step - loss: 0.0583 - val_loss: 0.0470 - learning_rate: 5.0000e-04
# Epoch 4/20
# 157/157 - 35s - 226ms/step - loss: 0.0548 - val_loss: 0.0450 - learning_rate: 5.0000e-04
# Epoch 5/20
# 157/157 - 34s - 217ms/step - loss: 0.0529 - val_loss: 0.0442 - learning_rate: 5.0000e-04
# Epoch 6/20
# 157/157 - 35s - 225ms/step - loss: 0.0516 - val_loss: 0.0443 - learning_rate: 5.0000e-04
# Epoch 7/20
# 157/157 - 34s - 220ms/step - loss: 0.0507 - val_loss: 0.0434 - learning_rate: 5.0000e-04
# Epoch 8/20
# 157/157 - 36s - 227ms/step - loss: 0.0502 - val_loss: 0.0451 - learning_rate: 5.0000e-04
# Epoch 9/20
# 157/157 - 36s - 232ms/step - loss: 0.0495 - val_loss: 0.0439 - learning_rate: 5.0000e-04
# Epoch 10/20
# 157/157 - 35s - 220ms/step - loss: 0.0493 - val_loss: 0.0417 - learning_rate: 5.0000e-04
# Epoch 11/20
# 157/157 - 36s - 228ms/step - loss: 0.0483 - val_loss: 0.0422 - learning_rate: 5.0000e-04
# Epoch 12/20
# 157/157 - 34s - 217ms/step - loss: 0.0479 - val_loss: 0.0415 - learning_rate: 5.0000e-04
# Epoch 13/20
# 157/157 - 36s - 227ms/step - loss: 0.0479 - val_loss: 0.0412 - learning_rate: 5.0000e-04
# Epoch 14/20
# 157/157 - 35s - 221ms/step - loss: 0.0477 - val_loss: 0.0412 - learning_rate: 5.0000e-04
# Epoch 15/20
# 157/157 - 38s - 243ms/step - loss: 0.0472 - val_loss: 0.0417 - learning_rate: 5.0000e-04
# Epoch 16/20
# 157/157 - 37s - 233ms/step - loss: 0.0471 - val_loss: 0.0415 - learning_rate: 5.0000e-04
# Epoch 17/20
# 157/157 - 35s - 225ms/step - loss: 0.0459 - val_loss: 0.0403 - learning_rate: 2.5000e-04
# Epoch 18/20
# 157/157 - 36s - 230ms/step - loss: 0.0459 - val_loss: 0.0403 - learning_rate: 2.5000e-04
# Epoch 19/20
# 157/157 - 33s - 213ms/step - loss: 0.0457 - val_loss: 0.0405 - learning_rate: 2.5000e-04
# Epoch 20/20
# 157/157 - 35s - 223ms/step - loss: 0.0455 - val_loss: 0.0400 - learning_rate: 2.5000e-04
# RMSE Comparison:
#   RMSE Train: 0.040
#   RMSE Val: 0.039
#   RMSE Test: 0.044
