# %%
from ipynb.fs.full.weather_pipeline import WeatherPipeline

# %%
# Configuration dictionary
config = {
    'data_path': './../data/',
    'file_name': 'weather_dataset_preprocesado.csv',
    #'columns_dataset': ['datetime', 'p (mbar)', 'T (degC)', 'Tpot (K)'], 
    'column_target': 'T (degC)',   
    'input_length': 24,
    'output_length': 1,
    'epochs': 20,
    'batch_size': 256,
    'learning_rate': 5e-4, #2.8e-4,
    'n_units': 256,
    'plot': True,
    'feature_engineering': True
}

pipeline = WeatherPipeline(config)
pipeline.run()
# Out:
# c:\Sevann\UBA\LSMT-weather\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 157/157 - 45s - 288ms/step - loss: 0.0706 - val_loss: 0.0370 - learning_rate: 5.0000e-04
# Epoch 2/20
# 157/157 - 45s - 285ms/step - loss: 0.0413 - val_loss: 0.0279 - learning_rate: 5.0000e-04
# Epoch 3/20
# 157/157 - 49s - 313ms/step - loss: 0.0351 - val_loss: 0.0250 - learning_rate: 5.0000e-04
# Epoch 4/20
# 157/157 - 49s - 311ms/step - loss: 0.0324 - val_loss: 0.0242 - learning_rate: 5.0000e-04
# Epoch 5/20
# 157/157 - 48s - 308ms/step - loss: 0.0311 - val_loss: 0.0236 - learning_rate: 5.0000e-04
# Epoch 6/20
# 157/157 - 49s - 311ms/step - loss: 0.0307 - val_loss: 0.0237 - learning_rate: 5.0000e-04
# Epoch 7/20
# 157/157 - 45s - 286ms/step - loss: 0.0302 - val_loss: 0.0248 - learning_rate: 5.0000e-04
# Epoch 8/20
# 157/157 - 42s - 270ms/step - loss: 0.0299 - val_loss: 0.0230 - learning_rate: 5.0000e-04
# Epoch 9/20
# 157/157 - 50s - 320ms/step - loss: 0.0294 - val_loss: 0.0242 - learning_rate: 5.0000e-04
# Epoch 10/20
# 157/157 - 49s - 314ms/step - loss: 0.0293 - val_loss: 0.0235 - learning_rate: 5.0000e-04
# Epoch 11/20
# 157/157 - 50s - 318ms/step - loss: 0.0291 - val_loss: 0.0228 - learning_rate: 5.0000e-04
# Epoch 12/20
# 157/157 - 49s - 313ms/step - loss: 0.0291 - val_loss: 0.0231 - learning_rate: 5.0000e-04
# Epoch 13/20
# 157/157 - 48s - 307ms/step - loss: 0.0288 - val_loss: 0.0244 - learning_rate: 5.0000e-04
# Epoch 14/20
# 157/157 - 48s - 306ms/step - loss: 0.0290 - val_loss: 0.0230 - learning_rate: 5.0000e-04
# Epoch 15/20
# 157/157 - 42s - 267ms/step - loss: 0.0279 - val_loss: 0.0227 - learning_rate: 2.5000e-04
# Epoch 16/20
# 157/157 - 37s - 233ms/step - loss: 0.0277 - val_loss: 0.0227 - learning_rate: 2.5000e-04
# Epoch 17/20
# 157/157 - 31s - 198ms/step - loss: 0.0278 - val_loss: 0.0226 - learning_rate: 2.5000e-04
# Epoch 18/20
# 157/157 - 30s - 190ms/step - loss: 0.0278 - val_loss: 0.0232 - learning_rate: 2.5000e-04
# Epoch 19/20
# 157/157 - 30s - 191ms/step - loss: 0.0277 - val_loss: 0.0225 - learning_rate: 2.5000e-04
# Epoch 20/20
# 157/157 - 30s - 192ms/step - loss: 0.0277 - val_loss: 0.0229 - learning_rate: 2.5000e-04
# RMSE Comparison:
#   RMSE Train: 0.023
#   RMSE Val: 0.022
#   RMSE Test: 0.026
